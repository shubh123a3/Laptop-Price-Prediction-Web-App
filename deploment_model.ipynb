# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('laptop_data_cleaned.csv')

# %%
value=df['Company'].value_counts()
value_repalce=value[value<8].index
df['Company']=df['Company'].replace(value_repalce,'Other')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,LabelEncoder,StandardScaler

# %%
x=df.drop('Price',axis=1)
y=df['Price']

# %%
df.sample()
# Out:
#      Company  TypeName  Ram  Weight      Price  TouchScreen  Ips         Ppi  \
# 648  Toshiba  Notebook    8     1.2  11.076413            0    0  165.632118
#
#          Cpu_brand  HDD  SSD Gpu_brand       Os
# 648  Intel Core i5    0  256     Intel  Windows

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y ,test_size=0.2, random_state=42)

# %%
cat_data=['Company','TypeName','Cpu_brand','Gpu_brand','Os']
num_data=['Ram','Weight','TouchScreen','Ips','Ppi','HDD','SSD']

# %%
preprocessor=ColumnTransformer([('num',StandardScaler(),num_data),
                                           ('cat',OneHotEncoder(),cat_data)])
model=RandomForestRegressor(max_depth=30,n_jobs=-1,max_features='sqrt', n_estimators=200)

# %%
pipe=Pipeline([('preprocessor',preprocessor),('model,',model)])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Ram', 'Weight',
#                                                    'TouchScreen', 'Ips', 'Ppi',
#                                                    'HDD', 'SSD']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['Company', 'TypeName',
#                                                    'Cpu_brand', 'Gpu_brand',
#                                                    'Os'])])),
#                 ('model,',
#                  RandomForestRegressor(max_depth=30, max_features='sqrt',
#                                        n_estimators=200, n_jobs=-1))])

# %%
y_pred=pipe.predict(X_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.888624356964284

# %%
import pickle
pickle.dump(pipe,open('model.pkl','wb'))

# %%
import joblib
import pandas as pd

# Dummy input data
input_data = {
    'feature1': 5.0,
    'feature2': 3.2,
    'feature3': 1.1,
    'feature4': 0.2
}

# Convert to DataFrame
input_df = pd.DataFrame([input_data])

# Load the model and pipeline
model = joblib.load('model.pkl')
pipeline = joblib.load('pipeline.pkl')

# Preprocess the input dat
preprocessed_input = pipe.transform(input_df)

# Make the prediction
prediction = model.predict(preprocessed_input)

# Print the result
print(f"The predicted result is: {prediction[0]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 17
#      15 # Load the model and pipeline
#      16 model = joblib.load('model.pkl')
# ---> 17 pipeline = joblib.load('pipeline.pkl')
#      19 # Preprocess the input dat
#      20 preprocessed_input = pipeline.transform(input_df)
#
# File ~\anaconda3\Lib\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pipeline.pkl'

# %%
X_train.sample()
# Out:
#     Company  TypeName  Ram  Weight  TouchScreen  Ips        Ppi  \
# 681    Asus  Notebook    4    1.86            0    0  100.45467
#
#                  Cpu_brand  HDD  SSD Gpu_brand       Os
# 681  Other Intel Processor    0  128     Intel  Windows

# %%
X_train['SSD'].unique()
# Out:
# array([ 256,  512,    0,  128,   32, 1024,  240, 1000,  180,    8,   16,
#         768,   64], dtype=int64)

# %%
df.sample()
# Out:
#     Company  TypeName  Ram  Weight     Price  TouchScreen  Ips         Ppi  \
# 889  Lenovo  Notebook    4     2.8  9.913097            0    0  106.113062
#
#          Cpu_brand  HDD  SSD Gpu_brand       Os
# 889  AMD Processor  500    0       AMD  Windows

# %%
df.isna().sum()
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         0
# Price          0
# TouchScreen    0
# Ips            0
# Ppi            0
# Cpu_brand      0
# HDD            0
# SSD            0
# Gpu_brand      0
# Os             0
# dtype: int64
